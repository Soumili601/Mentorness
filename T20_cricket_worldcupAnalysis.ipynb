# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install scikit-learn

# %%
data_t20=pd.read_csv(r'D:\python37\projects\t_20 World cup Analysis\data_t20.csv')

# %%
data_t20
# Out:
#       comment_id  match_id match_name home_team away_team current_innings  \
# 0            130   1298179  ENG v PAK       PAK       ENG             PAK
# 1            120   1298179  ENG v PAK       PAK       ENG             PAK
# 2            110   1298179  ENG v PAK       PAK       ENG             PAK
# 3            140   1298179  ENG v PAK       PAK       ENG             PAK
# 4            150   1298179  ENG v PAK       PAK       ENG             PAK
# ...          ...       ...        ...       ...       ...             ...
# 9809      218020   1298135   NAM v SL       NAM        SL              SL
# 9810      218030   1298135   NAM v SL       NAM        SL              SL
# 9811      218040   1298135   NAM v SL       NAM        SL              SL
# 9812      218050   1298135   NAM v SL       NAM        SL              SL
# 9813      218060   1298135   NAM v SL       NAM        SL              SL
#
#       innings_id  over  ball  runs  ... wicket_id     wkt_batsman_name  \
# ...

# %%
data_t20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9814 entries, 0 to 9813
# Data columns (total 44 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   comment_id         9814 non-null   int64
#  1   match_id           9814 non-null   int64
#  2   match_name         9814 non-null   object
#  3   home_team          9814 non-null   object
#  4   away_team          9814 non-null   object
#  5   current_innings    9814 non-null   object
#  6   innings_id         9814 non-null   int64
#  7   over               9814 non-null   int64
#  8   ball               9814 non-null   int64
#  9   runs               9814 non-null   int64
#  10  shortText          9814 non-null   object
#  11  isBoundary         9814 non-null   bool
#  12  isWide             9814 non-null   bool
#  13  isNoball           9814 non-null   bool
#  14  batsman1_id        9814 non-null   int64
#  15  batsman1_name      9814 non-null   object
# ...

# %%
data_t20.describe()
# Out:
#           comment_id      match_id   innings_id         over         ball  \
# count    9814.000000  9.814000e+03  9814.000000  9814.000000  9814.000000
# mean    85399.661708  1.298157e+06     1.477787    10.082841     3.486856
# std     78951.670137  1.355630e+01     0.499532     5.623045     1.707484
# min       110.000000  1.298135e+06     1.000000     1.000000     1.000000
# 25%     18030.000000  1.298145e+06     1.000000     5.000000     2.000000
# 50%     29010.000000  1.298157e+06     1.000000    10.000000     3.000000
# 75%    118040.000000  1.298169e+06     2.000000    15.000000     5.000000
# max    219090.000000  1.298179e+06     2.000000    20.000000     6.000000
#
#               runs   batsman1_id  batsman1_runs  batsman1_balls    bowler1_id  \
# count  9814.000000  9.814000e+03    9814.000000     9814.000000  9.814000e+03
# mean      1.202262  5.377303e+05      15.691971       13.249440  6.226676e+05
# ...

# %%
data_t20.isnull().sum()
# Out:
# comment_id              0
# match_id                0
# match_name              0
# home_team               0
# away_team               0
# current_innings         0
# innings_id              0
# over                    0
# ball                    0
# runs                    0
# shortText               0
# isBoundary              0
# isWide                  0
# isNoball                0
# batsman1_id             0
# batsman1_name           0
# batsman1_runs           0
# batsman1_balls          0
# bowler1_id              0
# bowler1_name            0
# bowler1_overs           0
# bowler1_maidens         0
# bowler1_runs            0
# bowler1_wkts            0
# batsman2_id             0
# batsman2_name           0
# batsman2_runs           0
# batsman2_balls          0
# bowler2_id            526
# bowler2_name          526
# bowler2_overs         526
# bowler2_maidens       526
# bowler2_runs          526
# bowler2_wkts          526
# wicket_id            9263
# ...

# %% [raw]
# #Data Cleaning

# %%
data_t20=data_t20.drop('isNoball',axis=1)

# %%
data_t20=data_t20.drop('isRetiredHurt',axis=1)

# %%
data_t20=data_t20.drop('isWide',axis=1)

# %%
data_t20=data_t20.drop('isBoundary',axis=1)

# %%
data_t20=data_t20.drop('bowler1_maidens',axis=1)

# %%
data_t20=data_t20.drop('bowler2_maidens',axis=1)

# %%
data_t20.head()
# Out:
#    comment_id  match_id match_name home_team away_team current_innings  \
# 0         130   1298179  ENG v PAK       PAK       ENG             PAK
# 1         120   1298179  ENG v PAK       PAK       ENG             PAK
# 2         110   1298179  ENG v PAK       PAK       ENG             PAK
# 3         140   1298179  ENG v PAK       PAK       ENG             PAK
# 4         150   1298179  ENG v PAK       PAK       ENG             PAK
#
#    innings_id  over  ball  runs  ... bowler2_wkts  wicket_id wkt_batsman_name  \
# 0           1     1     1     0  ...          NaN        NaN              NaN
# 1           1     1     1     1  ...          NaN        NaN              NaN
# 2           1     1     1     1  ...          NaN        NaN              NaN
# 3           1     1     2     2  ...          NaN        NaN              NaN
# 4           1     1     3     0  ...          NaN        NaN              NaN
#
#    wkt_bowler_name  wkt_batsman_runs  wkt_batsman_balls wkt_text  \
# ...

# %%
dr=data_t20.runs.value_counts()

# %%
db=data_t20.ball.value_counts()

# %%
dr.plot(kind='bar',figsize=[10,5])
plt.show()

# %%
db.plot(kind='bar')
plt.show()

# %%
do=data_t20.over.value_counts()

# %%
do.plot(kind='bar',figsize=[20,10])
plt.show()

# %%
db1=data_t20.batsman1_runs.value_counts()

# %%
db1.plot(kind='bar',figsize=[20,10])
plt.show()

# %%
db2=data_t20.batsman2_runs.value_counts()

# %%
db2.plot(kind='bar',figsize=[20,10])
plt.show()

# %%
data_t20.plot(x='batsman1_runs',y='batsman2_runs',kind='scatter',figsize=[20,10])
plt.show()

# %%
dbowler1=data_t20.bowler1_overs.value_counts()

# %%
dbowler1.plot(kind='bar',figsize=[20,10])
plt.show()

# %%
dbowler2=data_t20.bowler2_overs.value_counts()

# %%
dbowler2.plot(kind='bar',figsize=[20,10])
plt.show()

# %%
data_t20.plot(x='bowler1_overs',y='bowler2_overs',kind='scatter',figsize=[20,10])
plt.show()

# %%
dbowler1_run=data_t20.bowler1_runs.value_counts()

# %%
dbowler1_run.plot(kind='bar',figsize=[20,10])
plt.show()

# %%
dbowler2_run=data_t20.bowler2_runs.value_counts()

# %%
dbowler2_run.plot(kind='bar',figsize=[20,10])
plt.show()

# %%
data_t20.plot(x='bowler1_runs',y='bowler2_runs',kind='scatter',figsize=[20,10])
plt.show()

# %%
dbatsman1_ball=data_t20.batsman1_balls.value_counts()

# %%
dbatsman1_ball.plot(kind='bar',figsize=[20,10])
plt.show()

# %%
dbatsman2_ball=data_t20.batsman2_balls.value_counts()

# %%
dbatsman2_ball.plot(kind='bar',figsize=[20,10])
plt.show()

# %%
data_t20.plot(x='batsman1_balls',y='batsman2_balls',kind='scatter',figsize=[20,10])
plt.show()

# %%
data_t20.plot(x='runs',y='match_id',kind='scatter',figsize=[10,5])
plt.show()

# %%
data_t20.plot(x='over',y='match_id',kind='scatter',figsize=[10,5])
plt.show()

# %%
data_t20.plot(x='match_id',y='batsman1_runs',kind='scatter',figsize=[20,10])
plt.show()

# %%
data_t20.plot(x='match_id',y='batsman2_runs',kind='scatter',figsize=[20,10])
plt.show()

# %%
data_t20.plot(x='match_id',y='bowler1_runs',kind='scatter',figsize=[20,10])
plt.show()

# %%
data_t20.plot(x='match_id',y='bowler2_runs',kind='scatter',figsize=[20,10])
plt.show()

# %%
data_t20.plot(x='match_id',y='wkt_batsman_balls',kind='scatter',figsize=[20,10])
plt.show()

# %%
data_t20.plot(kind='box',figsize=[50,20])
plt.show()

# %%
Y=data_t20['text']

# %%
Y
# Out:
# 0       short again, and he gets some extra bounce on ...
# 1       and he'll have to bowl another free-hit after ...
# 2       full, and a hint of shape away from off stump....
# 3       shortish, angling down leg, gloves a pull down...
# 4       length ball close to off stump, straightens a ...
#                               ...
# 9809    slower ball on a length, waits for this and op...
# 9810    another slower ball, keeps very low. Bounces t...
# 9811    Almost cleans him up! Yorker finds it's way pa...
# 9812         short ball, goes for the uppercut and misses
# 9813    <b>And that's that!</b> Chameera looks to swin...
# Name: text, Length: 9814, dtype: object

# %%
X=data_t20['shortText']

# %%
X
# Out:
# 0          Stokes to Mohammad Rizwan, no run
# 1          Stokes to Mohammad Rizwan, 1 wide
# 2       Stokes to Mohammad Rizwan, 1 no ball
# 3          Stokes to Mohammad Rizwan, 2 runs
# 4          Stokes to Mohammad Rizwan, no run
#                         ...
# 9809              Wiese to Theekshana, 1 run
# 9810               Wiese to Chameera, no run
# 9811               Wiese to Chameera, no run
# 9812               Wiese to Chameera, no run
# 9813                  Wiese to Chameera, OUT
# Name: shortText, Length: 9814, dtype: object
